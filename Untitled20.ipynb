# %% [markdown]
# <a href="https://colab.research.google.com/github/Shangggggg/Krisha_10/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
url= 'https://raw.githubusercontent.com/Xxzero3211/Delete/main/titanic.csv'

# %%
data = pd.read_csv(url)

# %%
data=data[['Age','Fare']].dropna()

# %%
x=data['Age']. values.reshape(-1,1)

# %%
y=data['Fare']. values

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)

# %%
plt.scatter(x,y, color='blue',label='Data points')

# %%
plt.plot(x,y_pred,color='red',label='Linear fit')

# %%
plt.title('Linear Regression (Age vs Fare)')
# Out:
# Text(0.5, 1.0, 'Linear Regression (Age vs Fare)')

# %%
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.show()

# %%
print(f"Slope (Coefficient):{model.coef_[0]}")
# Out:
# Slope (Coefficient):0.34996368174402326

# %%
print(f"Intercept: {model.intercept_}")
# Out:
# Intercept: 24.300901449288645
